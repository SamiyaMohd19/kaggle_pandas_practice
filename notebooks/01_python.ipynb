# %%
import pandas as pd
data = {
    "Name": ["A","B","C"],
    "Age": [20,21,22]
}
df = pd.DataFrame(data)
print(df)
df.to_csv("sample.csv", index=False)
new_df = pd.read_csv("sample.csv")
print(new_df)
# Out:
#   Name  Age
# 0    A   20
# 1    B   21
# 2    C   22
#   Name  Age
# 0    A   20
# 1    B   21
# 2    C   22
