# %%
import pandas as pd

columns = ['engine_id', 'cycle',
           'op_setting1', 'op_setting2', 'op_setting3'] + \
          [f'sensor_{i}' for i in range(1, 22)]

train = pd.read_csv('../datasets/train_FD001.txt',
                    sep=r'\s+',
                    header=None)

train = train.dropna(axis=1)
train.columns = columns
# Rename a single column
train_renamed = train.rename(columns={'sensor_1': 'S1'})

train_renamed.head()
# Rename multiple columns
train_renamed = train.rename(columns={
    'sensor_1': 'S1',
    'sensor_2': 'S2'
})

train_renamed.head()
df1 = train.iloc[:1000]
df2 = train.iloc[1000:2000]

combined = pd.concat([df1, df2])

combined.head()
max_cycle = train.groupby('engine_id')['cycle'].max().reset_index()

merged = train.merge(max_cycle, on='engine_id')

merged.head()
# Out:
#    engine_id  cycle_x  op_setting1  op_setting2  op_setting3  sensor_1  \
# 0          1        1      -0.0007      -0.0004        100.0    518.67
# 1          1        2       0.0019      -0.0003        100.0    518.67
# 2          1        3      -0.0043       0.0003        100.0    518.67
# 3          1        4       0.0007       0.0000        100.0    518.67
# 4          1        5      -0.0019      -0.0002        100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    641.82   1589.70   1400.60     14.62  ...    2388.02    8138.62
# 1    642.15   1591.82   1403.14     14.62  ...    2388.07    8131.49
# 2    642.35   1587.99   1404.20     14.62  ...    2388.03    8133.23
# 3    642.35   1582.79   1401.87     14.62  ...    2388.08    8133.83
# 4    642.37   1582.85   1406.22     14.62  ...    2388.04    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...
