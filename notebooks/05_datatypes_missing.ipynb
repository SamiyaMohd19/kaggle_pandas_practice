# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Marks": [80, None, 85]
})

print(df.dtypes)

df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
print(df)
# Out:
# Marks    float64
# dtype: object
#    Marks
# 0   80.0
# 1   82.5
# 2   85.0
