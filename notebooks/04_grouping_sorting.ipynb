# %%
import pandas as pd

df = pd.DataFrame({
    "Class": ["X","X","Y"],
    "Marks": [80, 90, 85]
})

print(df.groupby("Class").mean())
print(df.sort_values(by="Marks"))
# Out:
#        Marks
# Class
# X       85.0
# Y       85.0
#   Class  Marks
# 0     X     80
# 2     Y     85
# 1     X     90
