# %%
import pandas as pd
df = pd.DataFrame({
    "Name": ["A","B","C"],
    "Marks": [80,91,85]
})
print(df)
print(df.loc[0])
print(df[df["Marks"]>80])
# Out:
#   Name  Marks
# 0    A     80
# 1    B     91
# 2    C     85
# Name      A
# Marks    80
# Name: 0, dtype: object
#   Name  Marks
# 1    B     91
# 2    C     85
